# %% [markdown]
# # DragonWood Probability Calculator

# %% [markdown]
# Do some imports...

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (8,6)
import dwood
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Answering Sample Probability Questions

# %% [markdown]
# Get the number of dice needed to roll at least a sum of 10 with a probability of at least 50%

# %%
dwood.get_num_die_thresh(T=10, CL=0.5)
# Out:
# 4

# %% [markdown]
# Get the probability of rolling a sum of 8 or greater using 3 dice

# %%
dwood.sum_gt_thresh_prob(N=3, T=8)
# Out:
# 0.5

# %% [markdown]
# ## Some Illustrative Plots...

# %%
dwood.plot_prob_vs_numdie(7)

# %%
dwood.plot_prob_vs_sum(6)

# %% [markdown]
# ## Threshold Sum Probability Distributions

# %% [markdown]
# ### 1 Die

# %%
dwood.plot_geprob_vs_thresh(N=1)

# %% [markdown]
# ### 2 Dice

# %%
dwood.plot_geprob_vs_thresh(N=2)

# %% [markdown]
# ### 3 Dice

# %%
dwood.plot_geprob_vs_thresh(N=3)

# %% [markdown]
# ### 4 Dice

# %%
dwood.plot_geprob_vs_thresh(N=4)

# %% [markdown]
# ### 5 Dice

# %%
dwood.plot_geprob_vs_thresh(N=5)

# %% [markdown]
# ### 6 Dice

# %%
dwood.plot_geprob_vs_thresh(N=6)
